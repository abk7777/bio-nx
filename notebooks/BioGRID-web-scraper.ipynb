# %% [markdown]
# # BioGRID Protein Interactions

# %% [markdown]
# ### Setup

# %%
import os
import sys
sys.path[0] = '../'
from dotenv import load_dotenv
import numpy as np
import pandas as pd
import re
from py2neo import Graph, Node, Relationship
from py2neo.ogm import GraphObject, Property

# %%
# Display options
pd.options.display.max_rows = None  # display all rows
pd.options.display.max_columns = None  # display all columns

# %%
# Set access key for BioGRID REST API
load_dotenv()
BIOGRID_ACCESS_KEY = os.getenv('BIOGRID_ACCESS_KEY')
NEO4J_HOME = os.getenv('NEO4J_HOME')
importDir = '/Users/gregory/Library/Application Support/Neo4j Desktop/Application/neo4jDatabases/database-d0b780b3-ce77-46cc-b7ed-bd0f78a46581/installation-3.5.14/import/'

# %%
# Select gene
gene = 'CYP1A2'
url = f'https://webservice.thebiogrid.org/interactions/?searchNames=true&geneList={gene}&taxId=9606&includeInteractors=true&includeInteractorInteractions=true&includeHeader=true&accesskey={BIOGRID_ACCESS_KEY}'

# %% [markdown]
# ### Import and Clean Data

# %%
# Load data
data = pd.read_csv(url, sep='\t', header=0)

# Remove leading hash character
data.rename(columns={"#BioGRID Interaction ID":"BioGRID Interaction ID"}, inplace=True)

# Replace pipe separators with commas
data = data.replace('\|', ',', regex=True)

# Concatenate all synonyms of genes
#data['Synonyms Interactor A'] = data['Official Symbol Interactor A'] + ',' + data['Synonyms Interactor A']
#data['Synonyms Interactor B'] = data['Official Symbol Interactor B'] + ',' + data['Synonyms Interactor B']

# Select str columns and replace '-' with np.nan
cols = ['Systematic Name Interactor A', 
      'Systematic Name Interactor B', 
      'Score', 
      'Modification', 
      'Phenotypes',
      'Qualifications',
      'Tags']

data[cols] = data[cols].applymap(lambda col: re.sub(r'^-$', str(np.NaN), col))

# Convert Score column to float
data['Score'] = data['Score'].astype('float64')

# %%
#data.reset_index()

# %%
data.to_csv('../data/clean/'+gene+'.csv', index=False)
data.to_csv(importDir+gene+'.csv', index=False)

# %%
pd.read_csv('../data/clean/'+gene+'.csv');

# %%
data.head()
# Out:
#    BioGRID Interaction ID  Entrez Gene Interactor A  Entrez Gene Interactor B  \
# 0                  303872                      2235                      2235
# 1                  305778                      5447                      1544
# 2                  831166                     10857                      5447
# 3                  831168                      5447                     10857
# 4                  833260                      5447                      1544
#
#    BioGRID ID Interactor A  BioGRID ID Interactor B  \
# 0                   108526                   108526
# 1                   111443                   107924
# 2                   116068                   111443
# 3                   111443                   116068
# 4                   111443                   107924
#
#   Systematic Name Interactor A Systematic Name Interactor B  \
# 0                          nan                          nan
# 1                          nan                          nan
# 2                          nan                          nan
# 3                          nan                          nan
# 4                          nan                          nan
#
#   Official Symbol Interactor A Official Symbol Interactor B  \
# 0                         FECH                         FECH
# 1                          POR                       CYP1A2
# 2                       PGRMC1                          POR
# 3                          POR                       PGRMC1
# 4                          POR                       CYP1A2
#
#   Synonyms Interactor A Synonyms Interactor B       Experimental System  \
# 0               EPP,FCE               EPP,FCE      Co-crystal Structure
# 1       CPR,CYPOR,P450R  CP12,P3-450,P450(PA)     Reconstituted Complex
# 2            HPR6.6,MPR       CPR,CYPOR,P450R  Affinity Capture-Western
# 3       CPR,CYPOR,P450R            HPR6.6,MPR  Affinity Capture-Western
# 4       CPR,CYPOR,P450R  CP12,P3-450,P450(PA)     Reconstituted Complex
#
#   Experimental System Type                     Author  Pubmed ID  \
# 0                 physical               Wu CK (2001)   11175906
# 1                 physical       Guengerich FP (1997)    9398194
# 2                 physical  Szczesna-Skorupa E (2011)   21081644
# 3                 physical  Szczesna-Skorupa E (2011)   21081644
# 4                 physical           Shimada T (2005)   15680923
#
#    Organism Interactor A  Organism Interactor B      Throughput  Score  \
# 0                   9606                   9606  Low Throughput    NaN
# 1                   9606                   9606  Low Throughput    NaN
# 2                   9606                   9606  Low Throughput    NaN
# 3                   9606                   9606  Low Throughput    NaN
# 4                   9606                   9606  Low Throughput    NaN
#
#   Modification Phenotypes Qualifications Tags Source Database
# 0          nan        nan            nan  nan         BIOGRID
# 1          nan        nan            nan  nan         BIOGRID
# 2          nan        nan            nan  nan         BIOGRID
# 3          nan        nan            nan  nan         BIOGRID
# 4          nan        nan            nan  nan         BIOGRID

# %%
# Select columns of interest for graph
graph_data = data[['BioGRID Interaction ID', 'Official Symbol Interactor A', 'Entrez Gene Interactor A', 
                   'Synonyms Interactor A', 'Organism Interactor A', 'Official Symbol Interactor B', 
                   'Entrez Gene Interactor B', 'Synonyms Interactor B', 'Organism Interactor B', 
                   'Author', 'Pubmed ID', 'Experimental System', 'Experimental System Type', 'Throughput']]

# %%
# Columns not selected for graph
set(data.columns)-set(graph_data.columns)
# Out:
# {'BioGRID ID Interactor A',
#  'BioGRID ID Interactor B',
#  'Modification',
#  'Phenotypes',
#  'Qualifications',
#  'Score',
#  'Source Database',
#  'Systematic Name Interactor A',
#  'Systematic Name Interactor B',
#  'Tags'}

# %%
graph_data
# Out:
#     BioGRID Interaction ID Official Symbol Interactor A  \
# 0                   303872                         FECH
# 1                   305778                          POR
# 2                   831166                       PGRMC1
# 3                   831168                          POR
# 4                   833260                          POR
# 5                   833263                       CYP1A2
# 6                   838618                        CYB5A
# 7                  1527656                       CYP1A2
# 8                  1870216                          POR
# 9                  2231171                       CYP1A2
# 10                 2247600                       CYP1A2
# 11                 2253759                       CYP1A2
# 12                 2264891                         FECH
# 13                 2270857                       CYP1A2
# 14                 2625925                       PGRMC1
# 15                 2727673                       CYP1A2
#
#     Entrez Gene Interactor A Synonyms Interactor A  Organism Interactor A  \
# 0                       2235               EPP,FCE                   9606
# 1                       5447       CPR,CYPOR,P450R                   9606
# 2                      10857            HPR6.6,MPR                   9606
# 3                       5447       CPR,CYPOR,P450R                   9606
# 4                       5447       CPR,CYPOR,P450R                   9606
# 5                       1544  CP12,P3-450,P450(PA)                   9606
# 6                       1528             CYB5,MCB5                   9606
# 7                       1544  CP12,P3-450,P450(PA)                   9606
# 8                       5447       CPR,CYPOR,P450R                   9606
# 9                       1544  CP12,P3-450,P450(PA)                   9606
# 10                      1544  CP12,P3-450,P450(PA)                   9606
# 11                      1544  CP12,P3-450,P450(PA)                   9606
# 12                      2235               EPP,FCE                   9606
# 13                      1544  CP12,P3-450,P450(PA)                   9606
# 14                     10857            HPR6.6,MPR                   9606
# 15                      1544  CP12,P3-450,P450(PA)                   9606
#
#    Official Symbol Interactor B  Entrez Gene Interactor B  \
# 0                          FECH                      2235
# 1                        CYP1A2                      1544
# 2                           POR                      5447
# 3                        PGRMC1                     10857
# 4                        CYP1A2                      1544
# 5                           POR                      5447
# 6                        CYP1A2                      1544
# 7                        CYP1A2                      1544
# 8                           POR                      5447
# 9                         ASAH1                       427
# 10                        EPHA4                      2043
# 11                         FECH                      2235
# 12                       PGRMC1                     10857
# 13                       PGRMC1                     10857
# 14                        CYB5A                      1528
# 15                      ABHD16A                      7920
#
#               Synonyms Interactor B  Organism Interactor B  \
# 0                           EPP,FCE                   9606
# 1              CP12,P3-450,P450(PA)                   9606
# 2                   CPR,CYPOR,P450R                   9606
# 3                        HPR6.6,MPR                   9606
# 4              CP12,P3-450,P450(PA)                   9606
# 5                   CPR,CYPOR,P450R                   9606
# 6              CP12,P3-450,P450(PA)                   9606
# 7              CP12,P3-450,P450(PA)                   9606
# 8                   CPR,CYPOR,P450R                   9606
# 9   AC,ACDase,ASAH,PHP,PHP32,SMAPME                   9606
# 10                   HEK8,SEK,TYRO1                   9606
# 11                          EPP,FCE                   9606
# 12                       HPR6.6,MPR                   9606
# 13                       HPR6.6,MPR                   9606
# 14                        CYB5,MCB5                   9606
# 15           BAT5,D6S82E,NG26,PP199                   9606
#
#                        Author  Pubmed ID       Experimental System  \
# 0                Wu CK (2001)   11175906      Co-crystal Structure
# 1        Guengerich FP (1997)    9398194     Reconstituted Complex
# 2   Szczesna-Skorupa E (2011)   21081644  Affinity Capture-Western
# 3   Szczesna-Skorupa E (2011)   21081644  Affinity Capture-Western
# 4            Shimada T (2005)   15680923     Reconstituted Complex
# 5            Shimada T (2005)   15680923     Reconstituted Complex
# 6            Shimada T (2005)   15680923     Reconstituted Complex
# 7              Reed JR (2012)   22738171                      FRET
# 8              Ozalp C (2005)   15980100                       PCA
# 9           Huttlin EL (2017)   28514442       Affinity Capture-MS
# 10          Huttlin EL (2017)   28514442       Affinity Capture-MS
# 11          Huttlin EL (2017)   28514442       Affinity Capture-MS
# 12          Huttlin EL (2017)   28514442       Affinity Capture-MS
# 13          Huttlin EL (2017)   28514442       Affinity Capture-MS
# 14       Moutaoufik MT (2019)   31536960          Co-fractionation
# 15              Luck K (2020)   32296183                Two-hybrid
#
#    Experimental System Type       Throughput
# 0                  physical   Low Throughput
# 1                  physical   Low Throughput
# 2                  physical   Low Throughput
# 3                  physical   Low Throughput
# 4                  physical   Low Throughput
# 5                  physical   Low Throughput
# 6                  physical   Low Throughput
# 7                  physical   Low Throughput
# 8                  physical   Low Throughput
# 9                  physical  High Throughput
# 10                 physical  High Throughput
# 11                 physical  High Throughput
# 12                 physical  High Throughput
# 13                 physical  High Throughput
# 14                 physical  High Throughput
# 15                 physical  High Throughput

# %%
graph_data.to_csv('../data/clean/graph_data.csv', index=False)

# %%
graph = Graph("bolt://localhost:7687", auth=("neo4j", "test"))

# %%
cyp1a2 = Node("Protein", name="CYP1A2")
fech = Node("Protein", name="FECH")

# %%
cyp1a2_fech = Relationship(cyp1a2, "INTERACTS_WITH", fech)

# %%
cyp1a2_fech["biogrid_interaction_id"] = "2253759"

# %%
tx = graph.begin()

# %%
entities = [cyp1a2, fech, cyp1a2_fech]

for entity in entities:
    tx.create(entity)
    
tx.commit()

# %%
graph.delete_all()

# %%
graph_data[graph_data['Official Symbol Interactor A']=='CYP1A2']
# Out:
#     BioGRID Interaction ID Official Symbol Interactor A  \
# 5                   833263                       CYP1A2
# 7                  1527656                       CYP1A2
# 9                  2231171                       CYP1A2
# 10                 2247600                       CYP1A2
# 11                 2253759                       CYP1A2
# 13                 2270857                       CYP1A2
# 15                 2727673                       CYP1A2
#
#     Entrez Gene Interactor A Synonyms Interactor A  Organism Interactor A  \
# 5                       1544  CP12,P3-450,P450(PA)                   9606
# 7                       1544  CP12,P3-450,P450(PA)                   9606
# 9                       1544  CP12,P3-450,P450(PA)                   9606
# 10                      1544  CP12,P3-450,P450(PA)                   9606
# 11                      1544  CP12,P3-450,P450(PA)                   9606
# 13                      1544  CP12,P3-450,P450(PA)                   9606
# 15                      1544  CP12,P3-450,P450(PA)                   9606
#
#    Official Symbol Interactor B  Entrez Gene Interactor B  \
# 5                           POR                      5447
# 7                        CYP1A2                      1544
# 9                         ASAH1                       427
# 10                        EPHA4                      2043
# 11                         FECH                      2235
# 13                       PGRMC1                     10857
# 15                      ABHD16A                      7920
#
#               Synonyms Interactor B  Organism Interactor B             Author  \
# 5                   CPR,CYPOR,P450R                   9606   Shimada T (2005)
# 7              CP12,P3-450,P450(PA)                   9606     Reed JR (2012)
# 9   AC,ACDase,ASAH,PHP,PHP32,SMAPME                   9606  Huttlin EL (2017)
# 10                   HEK8,SEK,TYRO1                   9606  Huttlin EL (2017)
# 11                          EPP,FCE                   9606  Huttlin EL (2017)
# 13                       HPR6.6,MPR                   9606  Huttlin EL (2017)
# 15           BAT5,D6S82E,NG26,PP199                   9606      Luck K (2020)
#
#     Pubmed ID    Experimental System Experimental System Type       Throughput
# 5    15680923  Reconstituted Complex                 physical   Low Throughput
# 7    22738171                   FRET                 physical   Low Throughput
# 9    28514442    Affinity Capture-MS                 physical  High Throughput
# 10   28514442    Affinity Capture-MS                 physical  High Throughput
# 11   28514442    Affinity Capture-MS                 physical  High Throughput
# 13   28514442    Affinity Capture-MS                 physical  High Throughput
# 15   32296183             Two-hybrid                 physical  High Throughput

# %% [markdown]
# ### Interactors

# %%
interactor_a = graph_data['Official Symbol Interactor A'].unique()
interactor_a
# Out:
# array(['FECH', 'POR', 'PGRMC1', 'CYP1A2', 'CYB5A'], dtype=object)

# %%
interactor_b = graph_data['Official Symbol Interactor B'].unique()
interactor_b
# Out:
# array(['FECH', 'CYP1A2', 'POR', 'PGRMC1', 'ASAH1', 'EPHA4', 'CYB5A',
#        'ABHD16A'], dtype=object)

# %%
# Genes not in interactor_a
set(interactor_a).symmetric_difference(set(interactor_b))
# Out:
# {'ABHD16A', 'ASAH1', 'EPHA4'}

# %%
set(interactor_a).union(set(interactor_b))
# Out:
# {'ABHD16A', 'ASAH1', 'CYB5A', 'CYP1A2', 'EPHA4', 'FECH', 'PGRMC1', 'POR'}

# %% [markdown]
# ### Entrez ID

# %%
entrez_id_a = graph_data['Entrez Gene Interactor A'].unique()
entrez_id_b = graph_data['Entrez Gene Interactor B'].unique()
set(entrez_id_a).union(set(entrez_id_b))
# Out:
# {427, 1528, 1544, 2043, 2235, 5447, 7920, 10857}

# %% [markdown]
# ### Create Nodes

# %%
# Create Interaction nodes
interaction_nodes = list(graph_data['BioGRID Interaction ID'].unique())

# Create Gene nodes
gene_nodes = list(set(interactor_a).union(set(interactor_b)))

# Create Article nodes
article_nodes = list(graph_data['Pubmed ID'].unique())

# Create Author nodes
author_nodes = list(graph_data['Author'].unique())
author_nodes = [' '.join(author.split()[:2]) for author in author_nodes]

# %%
nodes = [interaction_nodes, gene_nodes, article_nodes, author_nodes]

for node in nodes:
    print(node)
# Out:
# [303872, 305778, 831166, 831168, 833260, 833263, 838618, 1527656, 1870216, 2231171, 2247600, 2253759, 2264891, 2270857, 2625925, 2727673]
# ['FECH', 'CYB5A', 'ABHD16A', 'PGRMC1', 'CYP1A2', 'ASAH1', 'POR', 'EPHA4']
# [11175906, 9398194, 21081644, 15680923, 22738171, 15980100, 28514442, 31536960, 32296183]
# ['Wu CK', 'Guengerich FP', 'Szczesna-Skorupa E', 'Shimada T', 'Reed JR', 'Ozalp C', 'Huttlin EL', 'Moutaoufik MT', 'Luck K']

# %% [markdown]
# #### Interactions Nodes

# %%
# author property
interaction_author = graph_data[graph_data['BioGRID Interaction ID']==interaction_nodes[0]]['Author']
interaction_author = ', '.join(interaction_author.str.split(' ').str[:-1].loc[0])
interaction_author
# Out:
# 'Wu, CK'

# %%
# Build nodes
interaction = Node(biogrid_id=interaction_nodes[0], author = interaction_author)

# %%
# pubmed id property
interaction_pubmed_id = graph

# %%
class Interactions(GraphObject):
    __primarykey__ = "biogrid_id"
    
    author = Property()
    pubmed_id = Property()
    experimental_system = Property()
    experimental_system_type = Property()

# %% [markdown]
# #### Gene Nodes

# %%
class Gene(GraphObject):
    __primarykey__ = "name"
    
    name = Property()
    description = Property()
    entrez_id = Property()
    url = Property()
    synonyms = Property()
    organism = Property()
    locus_type = Property()
    wikipedia = Property()
